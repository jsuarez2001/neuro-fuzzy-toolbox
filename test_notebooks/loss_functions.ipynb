# %%
import torch
import torch.nn as nn

# %%
cross_entropy = nn.functional.cross_entropy

binary_cross_entropy = nn.functional.binary_cross_entropy
binary_cross_entropy_with_logits = nn.functional.binary_cross_entropy_with_logits

mse_loss = nn.functional.mse_loss

l1_loss = nn.functional.l1_loss
nll_loss = nn.functional.nll_loss
kl_div = nn.functional.kl_div
cosine_similarity = nn.functional.cosine_similarity
hinge_embedding_loss = nn.functional.hinge_embedding_loss
margin_ranking_loss = nn.functional.margin_ranking_loss
multi_margin_loss = nn.functional.multi_margin_loss
smooth_l1_loss = nn.functional.smooth_l1_loss
soft_margin_loss = nn.functional.soft_margin_loss
triplet_margin_loss = nn.functional.triplet_margin_loss
ctc_loss = nn.functional.ctc_loss
poisson_nll_loss = nn.functional.poisson_nll_loss

# %% [markdown]
# # Cross Entropy

# %%
input = torch.randn(3, 5, requires_grad=True, dtype=torch.float32)
target = torch.randint(5, (3,), dtype=torch.long)

# %%
torch.long == torch.int64
# Out:
# True

# %%
torch.double == torch.float64
# Out:
# True

# %%
torch.float == torch.float32
# Out:
# True

# %%
torch.half == torch.float16
# Out:
# True

# %%
input
# Out:
# tensor([[-0.1961, -0.5419, -0.7315, -1.6524,  1.3631],
#         [ 0.4666,  0.1013, -1.5226,  0.4668,  0.8545],
#         [ 2.6421, -0.8227, -0.6236,  1.0706,  1.3507]], requires_grad=True)

# %%
target
# Out:
# tensor([2, 4, 4])

# %%
input.dtype, target.dtype
# Out:
# (torch.float32, torch.int64)

# %%
cross_entropy(input, target)
# Out:
# tensor(1.7745, grad_fn=<NllLossBackward0>)

# %%
nnCrossEntropy = nn.CrossEntropyLoss()

input = torch.randn(3, 5, requires_grad=True)
target = torch.empty(3, dtype=torch.int32).random_(5)

# %%
input
# Out:
# tensor([[-1.5158, -0.6438, -0.3281,  0.2871,  0.9944],
#         [-0.4919,  0.2565, -1.0352,  0.5305, -1.8090],
#         [-0.2138, -1.0568, -0.9910, -0.0570, -0.5497]], requires_grad=True)

# %%
target
# Out:
# tensor([4, 1, 4], dtype=torch.int32)

# %%
input.dtype, target.dtype
# Out:
# (torch.float32, torch.int32)

# %%
nnCrossEntropy(input, target)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 nnCrossEntropy(input, target)
#
# File ~/workspaces/neuro-fuzzy-toolbox/env/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/workspaces/neuro-fuzzy-toolbox/env/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
# ...

# %% [markdown]
# # Binary Cross Entropy

# %%
input = torch.randn(3, 2, requires_grad=True)
target = torch.rand(3, 2, requires_grad=False, dtype=torch.double)

input
# Out:
# tensor([[ 0.5669, -2.7415],
#         [-0.6967, -0.6591],
#         [ 0.9948, -0.6479]], requires_grad=True)

# %%
target
# Out:
# tensor([[0.2922, 0.8680],
#         [0.5637, 0.2612],
#         [0.3486, 0.7247]], dtype=torch.float64)

# %%
b_input = torch.sigmoid(input)
b_input
# Out:
# tensor([[0.6381, 0.0606],
#         [0.3326, 0.3410],
#         [0.7300, 0.3435]], grad_fn=<SigmoidBackward0>)

# %%
b_input.dtype, target.dtype
# Out:
# (torch.float32, torch.float64)

# %%
binary_cross_entropy(b_input, target)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 binary_cross_entropy(b_input, target)
#
# File ~/workspaces/neuro-fuzzy-toolbox/env/lib/python3.12/site-packages/torch/nn/functional.py:3554, in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    3551     new_size = _infer_size(target.size(), weight.size())
#    3552     weight = weight.expand(new_size)
# -> 3554 return torch._C._nn.binary_cross_entropy(input, target, weight, reduction_enum)
#
# RuntimeError: Found dtype Double but expected Float
